# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("FinalLeetcode.csv")

# %%
df
# Out:
#                                                    Name  Percentage Difficulty
# 0                                  228. Summary Ranges         46.0       Easy
# 1                                           1. Two Sum         48.3       Easy
# 2                                   2. Add Two Numbers         38.0     Medium
# 3     3. Longest Substring Without Repeating Charact...        32.9     Medium
# 4                       4. Median of Two Sorted Arrays         33.7       Hard
# ...                                                 ...         ...        ...
# 2118  2146. K Highest Ranked Items Within a Price Ra...        40.0     Medium
# 2119    2147. Number of Ways to Divide a Long Corridor         39.8       Hard
# 2120  2148. Count Elements With Strictly Smaller and...        60.6       Easy
# 2121            2149. Rearrange Array Elements by Sign         82.0     Medium
# 2122        2150. Find All Lonely Numbers in the Array         60.3     Medium
#
# [2123 rows x 3 columns]

# %%
df.Name.drop_duplicates()
# Out:
# 0                                    228. Summary Ranges
# 1                                             1. Two Sum
# 2                                     2. Add Two Numbers
# 3       3. Longest Substring Without Repeating Charact...
# 4                         4. Median of Two Sorted Arrays
#                               ...
# 2118    2146. K Highest Ranked Items Within a Price Ra...
# 2119      2147. Number of Ways to Divide a Long Corridor
# 2120    2148. Count Elements With Strictly Smaller and...
# 2121              2149. Rearrange Array Elements by Sign
# 2122          2150. Find All Lonely Numbers in the Array
# Name: Name, Length: 2118, dtype: object

# %%
df["Percentage"] = df["Percentage"].astype(float)

# %%
df.groupby("Difficulty").describe()
# Out:
#            Percentage
#                 count       mean        std   min     25%   50%     75%   max
# Difficulty
#  Easy           536.0  63.275187  14.742756  25.8  51.900  63.2  75.025  95.8
#  Hard           453.0  45.966225  11.366582  14.1  37.600  44.4  53.200  86.5
#  Medium        1134.0  53.853086  13.696369  16.5  44.325  53.1  62.800  94.3

# %%
df.groupby("Difficulty").boxplot();

# %%
sns.catplot(x = "Difficulty", y = "Percentage", data = df);

# %%
sns.boxplot(x = df["Difficulty"], y = df["Percentage"]);

# %%
sns.violinplot(x = df["Difficulty"], y = df["Percentage"]);
